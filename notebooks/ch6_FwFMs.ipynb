# %% [markdown]
# # FwFMs (Field-weighted Factorization Machines)
# - [paper](https://arxiv.org/pdf/1806.03514.pdf)

# %%
# ![img1](FwFMs_notes.jpg)

# %%
from IPython.display import Image
from IPython.core.display import HTML
PATH = "/Users/johnson.huang/py_ds/tutor_python_project/notebooks/FwFMs_notes.jpg"
Image(filename = PATH, width=900, height=100)

# %% [markdown]
# <table>
# <tr><td colspan="4"><strong>PRELIMINARIES & Summary</strong></td></tr>
#
# <tr>
# <td colspan="1"><sub><a href="">Model</a></sub></td>
# <td colspan="1"><sub><a href="">Number of Parameters</a></sub></td>
# <td colspan="1" style="width: 300px;"><sub><a href="">Formula</a></sub></td>
# <td colspan="1" style="width: 300px;"><sub><a href="">Notes/Improvements</a></sub></td>
# </tr>
#
#
# <tr>
# <td colspan="1"><sub><a href="">LR (Logistic Regression)</a></sub></td>
# <td colspan="1" style="text-align: center;"><sub><a href="">m</a></sub></td>
# <td colspan="1" style="width: 300px;"><sub><a href="">$\begin{matrix} Φ_{LR}(w,x) = \sum_{i=1}^{m} x_{i} w_{i}  \end{matrix}$</a></sub></td>
# <td colspan="1" style="white-space: pre;"><sub><a href="">- linear combination of individual features
# - second line
#     </a></sub></td>
#
# </tr>
#
# </table>
